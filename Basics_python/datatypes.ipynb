# %%
age = 89
print(type(age))  # Should print <class 'int'>
# Out:
# <class 'int'>

# %%
result = age + 10
print(result)  # Should print 99.9
# Out:
# 99

# %%
result = "Hi , "   + str(10)
print(result)  # Should print " Hi 10"
# Out:
# Hi , 10

# %%
a = 10 
b = 5

add_result = a + b
sub_result = a - b
mul_result = a * b
div_result = a / b
mod_result = a % b
exp_result = a ** b
floor_result = a//b

print(add_result)
print(sub_result)
print(mul_result)

print(div_result)
print(mod_result)

print(exp_result)
print(floor_result)
# Out:
# 15
# 5
# 50
# 2.0
# 0
# 100000
# 2

# %% [markdown]
# ## If else conditinal statement

# %%
age = 17

if age >= 18:
    print("You are sexy bro")
else  :
    print("You are not sexy bro")
# Out:
# You are not sexy bro

# %%
# elif statement = multiple conditions 

# nested conditionals = condition inside a condition

num = int(input("Enter a number: "))

if num > 0:
    print("The number is positive")
    if num%2 == 0:
        print("The number is even")

    else:
        print("The number is odd ")

else:
    print("The number is negative")
# Out:
# The number is negative
