# %%
a= " shis "
dwpod  = "deid"
def gabo9():
    return 'ee'

gabo9()
# Out:
# 'ee'

# %%
a = ["Black ", " white " , " red " , "shshih"]
a[3] = 'green'
print(a)
# Out:
# ['Black ', ' white ', ' red ', 'green']

# %%
type = { " Masala cha" : "spicy" , " ginger " : " zesty " , " green " : " Mild "}
print(type)
# Out:
# {' Masala cha': 'spicy', ' ginger ': ' zesty ', ' green ': ' Mild '}

# %%
type.popitem()
# Out:
# (' green ', ' Mild ')

# %% [markdown]
# ## If conditional statement

# %%
age = int(input("Enter you age : "))

if age < 13:
    print("child")

elif age <20:
    print("teenage")

elif age < 60:
    print("adult")
else : 
    print("senior")
# Out:
# child

# %%
# Problem Solving 

age = int(input("Enter your age : "))
day = "Wednesday"

price = 12 if age >= 18 else 8

if day == "Wednesday":
    price = price-2

print("Ticket price :" ,price)
# Out:
# Ticket price : 6

# %%
# Grade Calclator

fruit = str(input("Enter your fruit colour:"))

if fruit == "yellow":
    print("ripe")
elif fruit =="green":
    print("Unripe")
elif  fruit == "brown":
    print("Overipe ")
# Out:
# Unripe

# %%
password = "Sahilsiddisi"

if len(password)<6:
    strength = "weak"
elif len(password) <=10:
    strength = "strong"
else : 
    strength = "very strong"

print(strength)
# Out:
# very strong

# %%
year = 2058

if (year % 400 == 0 ) or (year %4 == 0 and year % 100 != 0) :
    print(year ,"is a leap year" )
else :
    print("Not a year of leap ")
# Out:
# Not a year of leap

# %% [markdown]
# ## Loop statement

# %%
n = int(input("enter number"))

sum_even = 0

for i in range(1 , n+1 ):
    if i%2==0:
        sum_even += 1
print("sum of even number ", n)
# Out:
# sum of even number  44

# %%
number = 3

for i in range(1,11):
    if i == 5:
        continue
    print( number, ' X' , i , '=' , number * i)
# Out:
# 3  X 1 = 3
# 3  X 2 = 6
# 3  X 3 = 9
# 3  X 4 = 12
# 3  X 6 = 18
# 3  X 7 = 21
# 3  X 8 = 24
# 3  X 9 = 27
# 3  X 10 = 30

# %% [markdown]
# FUNCTIONS

# %%
def cal_sum(a , b):
    print(a*b)

cal_sum(23,64)
# Out:
# 1472

# %%
cube = lambda x: x**3  #Lamda fucntion 
print(cube(34))
# Out:
# 39304

# %%
#yield fucntion 

def even(limit):
    range

# %%
class Atm:
    #constructor 
    def __init__(self):
        self.pin = " "
        self.balance = 0


    # Object hei calss ko access kar sakta hai

# %%
obj  = Atm()

# %%
type(obj)
# Out:
# __main__.Atm
