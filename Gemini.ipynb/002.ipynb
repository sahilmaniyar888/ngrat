# %%
class Point:
    def __init__(self , x ,y):  #paramterized vlaue
    
        self.x_cod = x
        self.y_cod = y


    def __str__(self):
        return '<{},{}>'.format(self.x_cod,self.y_cod)
    

    def distance_from_origin(self):
        return (self.x_cod**2 + self.y_cod**2)**0.5

# %%
p2 = Point(30, 40)  #creating another object of class Point
print(p2)
# Out:
# <30,40>

# %%
class Function:

    def __init__(self,x,y):
        self.num = x
        self.den = y

    
    def __str__(self):    # to see how the object will be printed
        return '{}/{}'.format(self.num,self.den)
    

class Lines :

    def __init__(self,A ,B ,C):
        self.A = A
        self.B = B
        self.C = C

    def __str__(self):
        return '{}x + {}y + {} = 0'.format(self.A, self.B ,self.C)

    def point_on_line(line,point):
        if line.A * point.x_cod + line.B * point.y_cod + line.C == 0:
            return True
        return False

# %%
Lines1 = Lines(2,3,4)
print(Lines1)
Lines1.point_on_line(p2)  #checking if the point is on the line
# Out:
# 2x + 3y + 4 = 0
# False

# %%
fraction = Function(1,2)
print(fraction)
# Out:
# 1/2

# %%
class Car : 

    def __init__(self , brand , speed ):

        self.brand = brand
        self.speed = speed 


    def drive(self):
        return f"{self.brand} is fucking lesgoooo at {self.speed} km/h"
    

my_car = Car("BMW" , 200)

print(my_car.brand)
print(my_car.speed)
print(my_car.drive())
# Out:
# BMW
# 200
# BMW is fucking lesgoooo at 200 km/h

# %%
class Atm:

    def __init__(self, card_number, balance=0):
        self.card_number = card_number  # attributes 
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        return self.balance

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds")
        else:
            self.balance -= amount
        return self.balance

    def get_balance(self):
        return self.balance

# %%
account = Atm("1234-5678-9012-3456", 1000)  # creating an object of class Atm

# %%
print("Initial Balance:", account.get_balance())
# Out:
# Initial Balance: 1000

# %%
class BankAccount:

    def __init__(self ,owner , balance ):
        self.owner = owner 
        self.balance = balance 


    def deposit(self,amount):
        self.balance += amount
        print(f"{amount} deposited. New balance is {self.balance}")


    def withdraw(self,amount):
        if amount > self.balance:
            print(f"Insufficient funds. Current balance is {self.balance}")
        else:
            self.balance -= amount
            print(f"{amount} withdrawn. New balance is {self.balance}")

    def get_balance(self):
        return self.balance
    
    
    
account = BankAccount("John Doe", 5000)  # creating an object of class BankAccount
print(account.balance)
# Out:
# 5000

# %%
class Car :
    def __init__(self,windows,doors,enginetype):
        self.windows = windows
        self.doors = doors
        self.enginetype = enginetype 


    def drive(self):
        print(f"The person will drive the {self.enginetype} car.")

# %%
car1 = Car(4,4,"V8")

# %%
car1.drive()
# Out:
# The person will drive the V8 car.

# %%
class Tesla(Car):
    def __init__(self,windows , doors ,enginetype ,is_selfdriving ):
        super().__init__(windows , doors , enginetype )
        self.is_selfdriving = is_selfdriving

    def drive(self):
        if self.is_selfdriving:
            print(f"The self-driving Tesla is navigating.")
        else:
            print(f"The Tesla with {self.enginetype} engine is driving.")
