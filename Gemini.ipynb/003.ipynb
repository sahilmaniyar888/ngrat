# %%
# !pip install numpy

# %%
boolean_data = True
print(" The name of the bool data type is:", type(boolean_data))
# Out:
#  The name of the bool data type is: <class 'bool'>

# %%
num1 = 36
num2 = 2

print("Reminder =" , num1 % num2)
# Out:
# Reminder = 0

# %%
list1 = [1 , 2, 3]

for item in list1:
    print("The value of item is = " , item)
# Out:
# The value of item is =  1
# The value of item is =  2
# The value of item is =  3
