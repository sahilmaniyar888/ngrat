# %%
#Loop controls

#break, continue, pass


for i in range(10):
    if i == 5:
        print("Breaking at 5")
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# Breaking at 5

# %%
for i in range (10):
    if i == 5:
        print("Skipping 5")
        continue
# Out:
# Skipping 5

# %%
def avg():
    a= int(input("Enter first number: "))
    b= int(input("Enter second number: "))  

    sum = a + b
    print("Sum is: ", sum)

avg()
# Out:
# Sum is:  4562327

# %%
def greet():
    print("Hello, bitcoiners!")

greet()

#Function to call and user define function 

#Built in function 
len()
print()
range()
# Out:
# Hello, bitcoiners!

# %%
import numpy as np

# %%
z = np.array([1, 2, 3, 4, 5])
print(z)
# Out:
# [1 2 3 4 5]
