# %%
def shit():
    
    return
    
shit()

# %%
def find_greatest(a, b, c):
    if a >= b and a >= c:
        return a
    elif b >= a and b >= c:
        return b
    else:
        return c

find_greatest(12, 45, 20)
# Out:
# 45

# %%
def say_hello():
    return "Hello!"


say_hello()
# Out:
# 'Hello!'

# %%
def juice_machine(mango, orange):
    return mango + orange

x = juice_machine(3,6)
print( x )
# Out:
# 9
